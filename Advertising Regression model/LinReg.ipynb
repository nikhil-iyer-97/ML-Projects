# %%
import pandas as pd

# %%
data = pd.read_csv('Advertising.csv')
print(data.head())
#data.sort_values(by=['sales'],ascending=True,inplace=False)
# Out:
#    Unnamed: 0     TV  radio  newspaper  sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
data.shape
# Out:
# (200, 5)

# %%
import seaborn as sns
# %matplotlib inline

# %%
sns.pairplot(data,x_vars=['TV','radio','newspaper'],y_vars='sales',size=7,aspect=0.7,kind='reg')

# %%
feature_cols=['TV','radio','newspaper'] 
x = data[feature_cols]
x.tail()
# Out:
#         TV  radio  newspaper
# 195   38.2    3.7       13.8
# 196   94.2    4.9        8.1
# 197  177.0    9.3        6.4
# 198  283.6   42.0       66.2
# 199  232.1    8.6        8.7

# %%
print(type(x))
print(x.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# (200, 3)

# %%
y = data['sales']
y.tail()
# Out:
# 195     7.6
# 196     9.7
# 197    12.8
# 198    25.5
# 199    13.4
# Name: sales, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=1)

# %%
from sklearn.linear_model import LinearRegression
linreg = LinearRegression()
linreg.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
print(linreg.intercept_)
print(linreg.coef_)
zip(feature_cols,linreg.coef_)
# Out:
# 2.90794702082
# [ 0.0468431   0.17854434  0.00258619]

# %%
y_pred = linreg.predict(x_test)
print(y_pred)
print(y_test)

# %%
from sklearn import metrics
import numpy as np
print(np.sqrt(metrics.mean_squared_error(y_test,y_pred)))
# Out:
# 1.41134175586

# %%
new_data = pd.read_csv('Advertising.csv') 
new_data.head()
# Out:
#    Unnamed: 0     TV  radio  newspaper  sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
sns.pairplot(new_data,x_vars=['TV','radio','newspaper'],y_vars='sales',size=7,aspect=0.7,kind='reg')

# %%
feature_cols=['TV','radio']
x = new_data[feature_cols]
x.tail()
# Out:
#         TV  radio
# 195   38.2    3.7
# 196   94.2    4.9
# 197  177.0    9.3
# 198  283.6   42.0
# 199  232.1    8.6

# %%
y = data['sales']
y.tail()
# Out:
# 195     7.6
# 196     9.7
# 197    12.8
# 198    25.5
# 199    13.4
# Name: sales, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=1)

# %%
from sklearn.linear_model import LinearRegression
linreg = LinearRegression()
linreg.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
print(linreg.intercept_)
print(linreg.coef_)
zip(feature_cols,linreg.coef_)
# Out:
# 2.94751503603
# [ 0.04686997  0.1800065 ]

# %%
y_pred = linreg.predict(x_test)
from sklearn import metrics
import numpy as np
print(np.sqrt(metrics.mean_squared_error(y_test,y_pred)))
# Out:
# 1.39829248908
